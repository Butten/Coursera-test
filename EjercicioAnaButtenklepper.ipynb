# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ana Carolina Buttenklepper**<br>I currently analyzed customer behavior in a Mexican company.

# %% [markdown]
# <em>I am interested in data science because it is something I already do, but without any professional training. So being able to do my job with more knowledge and less margin of error is an opportunity for me. I am happy to have the opportunity to study Data Science and grow professionally. </em>

# %% [markdown]
# ### In the next block I want to show you a very simple python code. First I want to show you how with code I am going to report that the letter x is equivalent to the number one. and then i want to print the value of the letter x...In the next block I want to show you a very simple python code. First I want to show you how with code I am going to report that the letter x is equivalent to the number one. and that would be x=1 but it turns out that I would be interested in showing the value that was assigned to that letter x. It is simple in the line below followed by the command already written, you write ''print'' followed by a parenthesis between the letter that you want to show its numerical value. example print(x) and followed by that you click on the run button, and the code should succeed.

# %%
x=1
print(x)
# Out:
# 1

# %% [markdown]
# ---
# ***
# ___
#  - The recipe of coding
#  1. patients
#  1. curiosity
# | <span style='color:pink'>*#*</span> | <span style='color:blue'>**Things you need**</span> | <span style='color:gold'>**Price**</span> |
# | --- | --- | --- |
# | 1 |  *Brain*   | \$0 |
# | 2 | *Computer* | \$50|
# | 3 | *Internet* | \$5 |
#
#
#
# <span style='color:pink'>*Now I am going to show you one of the thousands of pages that helped me to do this work.*</span>
#
# [<span style='color:red'> Click here to see the page](https://www.folkstalk.com/2022/10/hyperlinks-in-jupyter-notebook-with-code-examples.html)
#
# To see how i did it [Click here](https://www.folkstalk.com/2022/10/hyperlinks-in-jupyter-notebook-with-code-examples.html)
#
# <img src="https://datasciencedojo.com/wp-content/uploads/79.jpg">
